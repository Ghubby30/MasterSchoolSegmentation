# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
# %matplotlib inline

# %%
test_phase_2 = pd.read_csv(r"C:\Users\Nicholas Jones\Desktop\PythonStuff\Top_Perk.csv")

# %%
#identify and correct duplicates
test_phase_2.drop_duplicates()
# Out:
#        user_id                               session_id  avg_hotel_occ_daily  \
# 0            0       0-fb09c770a739478e9748e3873a0efea4             4.651438
# 1          100     100-143cdbefdb1f4013ae8a06ef35187ce1                  NaN
# 2          100     100-3591be965c0e4f19812a8eb443994260            15.000000
# 3          100     100-56326f5513614c68a47b05f3de2cabf7                  NaN
# 4         1000    1000-7667c4c35b8a4e4c83350a9ae9855988                  NaN
# ...        ...                                      ...                  ...
# 49995   121741  121741-0292bdc2ecf04e8f8d98bf5c28b15ff9                  NaN
# 49996   121741  121741-440198711fa94294b030727167ae8f5d             2.644283
# 49997   121741  121741-761d371e950b40e28002600b2be63f3b             0.653891
# 49998   121741  121741-b877822b850d40d9933e80faa7cce90c                  NaN
# 49999   121742  121742-69a1abf61f434978bf40ef9aeea3be91                  NaN
#
#        total_bags  vacation_daily_difference  total_flight_discount_amt  \
# 0             0.0                        6.0                       0.05
# 1             NaN                        NaN                        NaN
# 2             NaN                        NaN                        NaN
# 3             0.0                        2.0                        NaN
# 4             NaN                        NaN                       0.15
# ...           ...                        ...                        ...
# 49995         NaN                        NaN                        NaN
# 49996         0.0                        4.0                        NaN
# 49997         0.0                        2.0                        NaN
# 49998         0.0                        0.0                        NaN
# 49999         NaN                        NaN                        NaN
#
#        total_hotel_discount_amt  num_flights_booked  num_hotels_booked  \
# 0                           NaN                   1                  1
# 1                           NaN                   1                  1
# 2                           NaN                   1                  1
# 3                           NaN                   1                  1
# 4                          0.15                   1                  1
# ...                         ...                 ...                ...
# 49995                       NaN                   1                  1
# 49996                       NaN                   1                  1
# 49997                       NaN                   1                  1
# 49998                      0.10                   1                  1
# 49999                       NaN                   1                  1
#
#        total_clicks  no_cancel_num  avg_session_time  all_discounts  \
# 0              40.0            2.0              4.93            NaN
# 1              36.0            NaN              4.45            NaN
# 2              18.0            NaN              2.23            NaN
# 3              20.0            NaN              2.50            NaN
# 4               9.0            NaN              1.13           0.15
# ...             ...            ...               ...            ...
# 49995          10.0            NaN              1.27            NaN
# 49996          23.0            2.0              2.77            NaN
# 49997          17.0            2.0              2.07            NaN
# 49998          16.0            NaN              2.03            NaN
# 49999          26.0            NaN              3.22            NaN
#
#        original_pay
# 0            205.16
# 1               NaN
# 2               NaN
# 3            761.40
# 4               NaN
# ...             ...
# 49995           NaN
# 49996        237.65
# 49997        159.02
# 49998         52.93
# 49999           NaN
#
# [50000 rows x 14 columns]

# %%
#identify and fix missing values
#change sessions to strings
test_phase_2.session_id.isna().value_counts()
test_phase_2.session_id.apply(lambda x:str(x))
test_phase_2.session_id.info
# Out:
# <bound method Series.info of 0             0-fb09c770a739478e9748e3873a0efea4
# 1           100-143cdbefdb1f4013ae8a06ef35187ce1
# 2           100-3591be965c0e4f19812a8eb443994260
# 3           100-56326f5513614c68a47b05f3de2cabf7
# 4          1000-7667c4c35b8a4e4c83350a9ae9855988
#                           ...
# 49995    121741-0292bdc2ecf04e8f8d98bf5c28b15ff9
# 49996    121741-440198711fa94294b030727167ae8f5d
# 49997    121741-761d371e950b40e28002600b2be63f3b
# 49998    121741-b877822b850d40d9933e80faa7cce90c
# 49999    121742-69a1abf61f434978bf40ef9aeea3be91
# Name: session_id, Length: 50000, dtype: object>

# %%
test_phase_2.avg_hotel_occ_daily.isna().value_counts()
test_phase_2.avg_hotel_occ_daily.fillna(0)
test_phase_2['avg_hotel_occ_daily'] = test_phase_2.avg_hotel_occ_daily.fillna(0)

# %%
test_phase_2.total_bags.isna().value_counts()
test_phase_2.total_bags.fillna(0)
test_phase_2['total_bags']= test_phase_2.total_bags.fillna(0)

# %%
test_phase_2.vacation_daily_difference.isna().value_counts()
test_phase_2.vacation_daily_difference.fillna(0)
test_phase_2['vacation_daily_difference']=test_phase_2.vacation_daily_difference.fillna(0)

# %%
test_phase_2.total_flight_discount_amt.isna().value_counts()
test_phase_2.total_flight_discount_amt.fillna(0)
test_phase_2['total_flight_discount_amt']=test_phase_2.total_flight_discount_amt.fillna(0)

# %%
test_phase_2.total_hotel_discount_amt.isna().value_counts()
test_phase_2.total_hotel_discount_amt.fillna(0)
test_phase_2['total_hotel_discount_amt']=test_phase_2.total_hotel_discount_amt.fillna(0)

# %%
test_phase_2.num_flights_booked.isna().value_counts()
# Out:
# num_flights_booked
# False    50000
# Name: count, dtype: int64

# %%
test_phase_2.num_hotels_booked.isna().value_counts()
# Out:
# num_hotels_booked
# False    50000
# Name: count, dtype: int64

# %%
test_phase_2.total_clicks.isna().value_counts()
# Out:
# total_clicks
# False    50000
# Name: count, dtype: int64

# %%
test_phase_2.no_cancel_num.isna().value_counts()
test_phase_2.no_cancel_num.fillna(0)
test_phase_2['no_cancel_num']=test_phase_2.no_cancel_num.fillna(0)

# %%
test_phase_2.avg_session_time.isna().value_counts()
# Out:
# avg_session_time
# False    50000
# Name: count, dtype: int64

# %%
test_phase_2.all_discounts.isna().value_counts()
test_phase_2.all_discounts.fillna(0)
test_phase_2['all_discounts']=test_phase_2.all_discounts.fillna(0)

# %%
test_phase_2.original_pay.isna().value_counts()
test_phase_2.original_pay.fillna(0)
test_phase_2['original_pay']=test_phase_2.original_pay.fillna(0)

# %%
#test if there are any more nulls
test_phase_2.isna()
test_phase_2
# Out:
#        user_id                               session_id  avg_hotel_occ_daily  \
# 0            0       0-fb09c770a739478e9748e3873a0efea4             4.651438
# 1          100     100-143cdbefdb1f4013ae8a06ef35187ce1             0.000000
# 2          100     100-3591be965c0e4f19812a8eb443994260            15.000000
# 3          100     100-56326f5513614c68a47b05f3de2cabf7             0.000000
# 4         1000    1000-7667c4c35b8a4e4c83350a9ae9855988             0.000000
# ...        ...                                      ...                  ...
# 49995   121741  121741-0292bdc2ecf04e8f8d98bf5c28b15ff9             0.000000
# 49996   121741  121741-440198711fa94294b030727167ae8f5d             2.644283
# 49997   121741  121741-761d371e950b40e28002600b2be63f3b             0.653891
# 49998   121741  121741-b877822b850d40d9933e80faa7cce90c             0.000000
# 49999   121742  121742-69a1abf61f434978bf40ef9aeea3be91             0.000000
#
#        total_bags  vacation_daily_difference  total_flight_discount_amt  \
# 0             0.0                        6.0                       0.05
# 1             0.0                        0.0                       0.00
# 2             0.0                        0.0                       0.00
# 3             0.0                        2.0                       0.00
# 4             0.0                        0.0                       0.15
# ...           ...                        ...                        ...
# 49995         0.0                        0.0                       0.00
# 49996         0.0                        4.0                       0.00
# 49997         0.0                        2.0                       0.00
# 49998         0.0                        0.0                       0.00
# 49999         0.0                        0.0                       0.00
#
#        total_hotel_discount_amt  num_flights_booked  num_hotels_booked  \
# 0                          0.00                   1                  1
# 1                          0.00                   1                  1
# 2                          0.00                   1                  1
# 3                          0.00                   1                  1
# 4                          0.15                   1                  1
# ...                         ...                 ...                ...
# 49995                      0.00                   1                  1
# 49996                      0.00                   1                  1
# 49997                      0.00                   1                  1
# 49998                      0.10                   1                  1
# 49999                      0.00                   1                  1
#
#        total_clicks  no_cancel_num  avg_session_time  all_discounts  \
# 0              40.0            2.0              4.93           0.00
# 1              36.0            0.0              4.45           0.00
# 2              18.0            0.0              2.23           0.00
# 3              20.0            0.0              2.50           0.00
# 4               9.0            0.0              1.13           0.15
# ...             ...            ...               ...            ...
# 49995          10.0            0.0              1.27           0.00
# 49996          23.0            2.0              2.77           0.00
# 49997          17.0            2.0              2.07           0.00
# 49998          16.0            0.0              2.03           0.00
# 49999          26.0            0.0              3.22           0.00
#
#        original_pay
# 0            205.16
# 1              0.00
# 2              0.00
# 3            761.40
# 4              0.00
# ...             ...
# 49995          0.00
# 49996        237.65
# 49997        159.02
# 49998         52.93
# 49999          0.00
#
# [50000 rows x 14 columns]

# %%
test_phase_2.original_pay.describe()
# Out:
# count    50000.000000
# mean       356.449634
# std        941.801644
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%        399.147500
# max      21135.530000
# Name: original_pay, dtype: float64

# %%
# Testing the correlation of the variables Part 1--------------------> Correlations
ties = test_phase_2.iloc[:, [i for i in range(2,14)]].corr()
print(ties)
# Out:
#                            avg_hotel_occ_daily  total_bags  \
# avg_hotel_occ_daily                   1.000000    0.145980
# total_bags                            0.145980    1.000000
# vacation_daily_difference             0.441174    0.435682
# total_flight_discount_amt            -0.011466   -0.022502
# total_hotel_discount_amt              0.027040   -0.017245
# num_flights_booked                         NaN         NaN
# num_hotels_booked                          NaN         NaN
# total_clicks                          0.098463    0.141606
# no_cancel_num                         0.349195    0.421210
# avg_session_time                      0.099882    0.160509
# all_discounts                         0.009358   -0.016223
# original_pay                          0.149254    0.521879
#
#                            vacation_daily_difference  \
# avg_hotel_occ_daily                         0.441174
# total_bags                                  0.435682
# vacation_daily_difference                   1.000000
# total_flight_discount_amt                  -0.040058
# total_hotel_discount_amt                   -0.017130
# num_flights_booked                               NaN
# num_hotels_booked                                NaN
# total_clicks                                0.225476
# no_cancel_num                               0.415885
# avg_session_time                            0.292246
# all_discounts                              -0.018368
# original_pay                                0.541587
#
#                            total_flight_discount_amt  \
# avg_hotel_occ_daily                        -0.011466
# total_bags                                 -0.022502
# vacation_daily_difference                  -0.040058
# total_flight_discount_amt                   1.000000
# total_hotel_discount_amt                    0.022434
# num_flights_booked                               NaN
# num_hotels_booked                                NaN
# total_clicks                               -0.033251
# no_cancel_num                              -0.017818
# avg_session_time                           -0.048532
# all_discounts                               0.351983
# original_pay                               -0.025193
#
#                            total_hotel_discount_amt  num_flights_booked  \
# avg_hotel_occ_daily                        0.027040                 NaN
# total_bags                                -0.017245                 NaN
# vacation_daily_difference                 -0.017130                 NaN
# total_flight_discount_amt                  0.022434                 NaN
# total_hotel_discount_amt                   1.000000                 NaN
# num_flights_booked                              NaN                 NaN
# num_hotels_booked                               NaN                 NaN
# total_clicks                              -0.031977                 NaN
# no_cancel_num                             -0.015009                 NaN
# avg_session_time                          -0.045084                 NaN
# all_discounts                              0.374967                 NaN
# original_pay                              -0.020681                 NaN
#
#                            num_hotels_booked  total_clicks  no_cancel_num  \
# avg_hotel_occ_daily                      NaN      0.098463       0.349195
# total_bags                               NaN      0.141606       0.421210
# vacation_daily_difference                NaN      0.225476       0.415885
# total_flight_discount_amt                NaN     -0.033251      -0.017818
# total_hotel_discount_amt                 NaN     -0.031977      -0.015009
# num_flights_booked                       NaN           NaN            NaN
# num_hotels_booked                        NaN           NaN            NaN
# total_clicks                             NaN      1.000000       0.143337
# no_cancel_num                            NaN      0.143337       1.000000
# avg_session_time                         NaN      0.724714       0.072820
# all_discounts                            NaN     -0.015253      -0.019280
# original_pay                             NaN      0.181067       0.286278
#
#                            avg_session_time  all_discounts  original_pay
# avg_hotel_occ_daily                0.099882       0.009358      0.149254
# total_bags                         0.160509      -0.016223      0.521879
# vacation_daily_difference          0.292246      -0.018368      0.541587
# total_flight_discount_amt         -0.048532       0.351983     -0.025193
# total_hotel_discount_amt          -0.045084       0.374967     -0.020681
# num_flights_booked                      NaN            NaN           NaN
# num_hotels_booked                       NaN            NaN           NaN
# total_clicks                       0.724714      -0.015253      0.181067
# no_cancel_num                      0.072820      -0.019280      0.286278
# avg_session_time                   1.000000      -0.020388      0.266842
# all_discounts                     -0.020388       1.000000     -0.010796
# original_pay                       0.266842      -0.010796      1.000000

# %%
# Testing the correlation of the variables Part 2--------------> Pair Plot
sbn.pairplot(ties[['avg_hotel_occ_daily','total_bags','no_cancel_num','all_discounts','original_pay']])
# Out:
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Testing the correlation of the variables Part 3----------------> Heatmap
sbn.heatmap(ties)
# Out:
# <Axes: >

# %%
#Scale All relevant variables using MinMax Technique
test_phase_2['avg_hotel_occ_daily']=test_phase_2['avg_hotel_occ_daily'].map(lambda x: (x-test_phase_2['avg_hotel_occ_daily'].min())/(test_phase_2['avg_hotel_occ_daily'].max()-test_phase_2['avg_hotel_occ_daily'].min()))
test_phase_2['total_bags']=test_phase_2['total_bags'].map(lambda x: (x-test_phase_2['total_bags'].min())/(test_phase_2['total_bags'].max()-test_phase_2['total_bags'].min()))

# %%
test_phase_2['vacation_daily_difference']=test_phase_2['vacation_daily_difference'].map(lambda x: (x-test_phase_2['vacation_daily_difference'].min())/(test_phase_2['vacation_daily_difference'].max()-test_phase_2['vacation_daily_difference'].min()))
test_phase_2['total_flight_discount_amt']=test_phase_2['total_flight_discount_amt'].map(lambda x: (x-test_phase_2['total_flight_discount_amt'].min())/(test_phase_2['total_flight_discount_amt'].max()-test_phase_2['total_flight_discount_amt'].min()))

# %%
test_phase_2['total_hotel_discount_amt']=test_phase_2['total_hotel_discount_amt'].map(lambda x: (x-test_phase_2['total_hotel_discount_amt'].min())/(test_phase_2['total_hotel_discount_amt'].max()-test_phase_2['total_hotel_discount_amt'].min()))
test_phase_2['total_clicks']=test_phase_2['total_clicks'].map(lambda x: (x-test_phase_2['total_clicks'].min())/(test_phase_2['total_clicks'].max()-test_phase_2['total_clicks'].min()))

# %%
test_phase_2['avg_session_time']=test_phase_2['avg_session_time'].map(lambda x: (x-test_phase_2['avg_session_time'].min())/(test_phase_2['avg_session_time'].max()-test_phase_2['avg_session_time'].min()))

# %%
test_phase_2['all_discounts']=test_phase_2['all_discounts'].map(lambda x: (x-test_phase_2['all_discounts'].min())/(test_phase_2['all_discounts'].max()-test_phase_2['all_discounts'].min()))
test_phase_2['original_pay']=test_phase_2['original_pay'].map(lambda x: (x-test_phase_2['original_pay'].min())/(test_phase_2['original_pay'].max()-test_phase_2['original_pay'].min()))

# %%
test_phase_2.no_cancel_num=test_phase_2.no_cancel_num.map(lambda x: (x-test_phase_2['no_cancel_num'].min())/(test_phase_2['no_cancel_num'].max()-test_phase_2['no_cancel_num'].min()))

# %%
#look at the scaled results
test_phase_2
# Out:
#        user_id                               session_id  avg_hotel_occ_daily  \
# 0            0       0-fb09c770a739478e9748e3873a0efea4             0.091042
# 1          100     100-143cdbefdb1f4013ae8a06ef35187ce1             0.021751
# 2          100     100-3591be965c0e4f19812a8eb443994260             0.245203
# 3          100     100-56326f5513614c68a47b05f3de2cabf7             0.021751
# 4         1000    1000-7667c4c35b8a4e4c83350a9ae9855988             0.021751
# ...        ...                                      ...                  ...
# 49995   121741  121741-0292bdc2ecf04e8f8d98bf5c28b15ff9             0.021751
# 49996   121741  121741-440198711fa94294b030727167ae8f5d             0.061142
# 49997   121741  121741-761d371e950b40e28002600b2be63f3b             0.031492
# 49998   121741  121741-b877822b850d40d9933e80faa7cce90c             0.021751
# 49999   121742  121742-69a1abf61f434978bf40ef9aeea3be91             0.021751
#
#        total_bags  vacation_daily_difference  total_flight_discount_amt  \
# 0             0.0                   0.103448                   0.071429
# 1             0.0                   0.000000                   0.000000
# 2             0.0                   0.000000                   0.000000
# 3             0.0                   0.034483                   0.000000
# 4             0.0                   0.000000                   0.214286
# ...           ...                        ...                        ...
# 49995         0.0                   0.000000                   0.000000
# 49996         0.0                   0.068966                   0.000000
# 49997         0.0                   0.034483                   0.000000
# 49998         0.0                   0.000000                   0.000000
# 49999         0.0                   0.000000                   0.000000
#
#        total_hotel_discount_amt  num_flights_booked  num_hotels_booked  \
# 0                           0.0                   1                  1
# 1                           0.0                   1                  1
# 2                           0.0                   1                  1
# 3                           0.0                   1                  1
# 4                           0.3                   1                  1
# ...                         ...                 ...                ...
# 49995                       0.0                   1                  1
# 49996                       0.0                   1                  1
# 49997                       0.0                   1                  1
# 49998                       0.2                   1                  1
# 49999                       0.0                   1                  1
#
#        total_clicks  no_cancel_num  avg_session_time  all_discounts  \
# 0          0.013257       0.117647          0.033837       0.000000
# 1          0.011600       0.000000          0.029807       0.000000
# 2          0.004143       0.000000          0.011167       0.000000
# 3          0.004971       0.000000          0.013434       0.000000
# 4          0.000414       0.000000          0.001931       0.352941
# ...             ...            ...               ...            ...
# 49995      0.000829       0.000000          0.003107       0.000000
# 49996      0.006214       0.117647          0.015701       0.000000
# 49997      0.003729       0.117647          0.009824       0.000000
# 49998      0.003314       0.000000          0.009488       0.000000
# 49999      0.007457       0.000000          0.019479       0.000000
#
#        original_pay
# 0          0.009707
# 1          0.000000
# 2          0.000000
# 3          0.036025
# 4          0.000000
# ...             ...
# 49995      0.000000
# 49996      0.011244
# 49997      0.007524
# 49998      0.002504
# 49999      0.000000
#
# [50000 rows x 14 columns]

# %%
#Plot of the segementation varible
plt.hist(test_phase_2.vacation_daily_difference)
plt.title(f'The Histogram for the segmentation variable: vacation_daily_difference')
plt.show()

# %%
# Segment the data based on standard deviation of the Vacation Daily Difference
SD=test_phase_2.vacation_daily_difference.std()
print(SD)
# Out:
# 0.07106363087665117

# %%
M=test_phase_2.vacation_daily_difference.mean()
print(M)
# Out:
# 0.045237931034482766

# %%
#Segemntation Formula:  I segement the data based on the Vacation_Daily_Difference variable but within 3 stds of the mean
seg = []
k = [3/5,6/5,9/5,12/5,15/5]
def assign (a,seg):
        for i in range(len(a)):
            if M-k[0]*SD <= a[i] < M+k[0]*SD:
                b = "G"+str(1)
                seg.append(b)
            elif M-k[1]*SD <= a[i] < M+k[1]*SD:
                b = "G"+str(2)
                seg.append(b)
            elif M-k[2]*SD <= a[i] < M+k[2]*SD:
                b = "G"+str(3)
                seg.append(b)
            elif M-k[3]*SD <= a[i] < M+k[3]*SD:
                b = "G"+str(4)
                seg.append(b)
            elif M-k[4]*SD <= a[i] < M+k[4]*SD:
                b = "G"+str(5)
                seg.append(b)
            else:
                b="Outlier"
                seg.append(b);
x = assign(test_phase_2.vacation_daily_difference, seg) 
print (seg)
# Out:
# ['G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G1', 'G3', 'G2', 'G1', 'G2', 'G1', 'G1', 'G1', 'G4', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'Outlier', 'G2', 'G2', 'G5', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G1', 'G1', 'G3', 'G1', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G1', 'Outlier', 'G1', 'G1', 'G2', 'G4', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G4', 'G4', 'G1', 'G2', 'G1', 'G2', 'G2', 'G2', 'G1', 'G2', 'G1', 'G2', 'G2', 'G1', 'G2', 'G2', 'G1', 'G2', 'G5', 'G3', 'Outlier', 'G2', 'G2', 'G1', 'G1', 'G2', 'G1', 'G1', 'G2', 'G2', 'G1', 'G2', 'G1', 'G3', 'G1', 'G1', 'G2', 'G2', 'G2', 'G2', 'G1', 'G1', 'G2', 'G2', 'G1', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'Outlier', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G3', 'G2', 'G1', 'G3', 'G2', 'G1', 'G1', 'G2', 'G3', 'G1', 'G2', 'G2', 'G2', 'G1', 'G2', 'G1', 'G1', 'G2', 'G2', 'G2', 'G1', 'G2', 'G1', 'G2', 'G2', 'G1', 'G1', 'G2', 'G2', 'G2', 'G1', 'G1', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G3', 'G1', 'G2', 'G2', 'G2', 'G1', 'G2', 'G1', 'G1', 'G1', 'G1', 'G2', 'G1', 'G2', 'G2', 'G1', 'G2', 'G1', 'G1', 'G2', 'G1', 'G2', 'G1', 'G1', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G1', 'Outlier', 'G2', 'G2', 'G1', 'G2', 'G1', 'G2', 'G1', 'G2', 'G1', 'G2', 'G1', 'G1', 'G1', 'G1', 'G2', 'G1', 'G2', 'G2', 'G2', 'G3', 'G2', 'G2', 'G5', 'G2', 'G2', 'G1', 'G2', 'G2', 'G1', 'G2', 'G1', 'G1', 'G2', 'G3', 'G1', 'G2', 'G1', 'G1', 'G2', 'G1', 'G2', 'G2', 'G4', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G1', 'G2', 'G3', 'G3', 'G2', 'G2', 'G1', 'G2', 'G2', 'G1', 'G1', 'G2', 'G1', 'G1', 'G1', 'G5', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G3', 'G2', 'G1', 'G1', 'G1', 'G2', 'G2', 'G1', 'G1', 'G2', 'G1', 'G3', 'G2', 'G1', 'G2', 'G2', 'G1', 'G1', 'G1', 'G1', 'G1', 'G2', 'G2', 'G1', 'G2', 'G2', 'G1', 'G2', 'G2', 'Outlier', 'G2', 'G2', 'G2', 'G1', 'G2', 'G4', 'G2', 'G3', 'G2', 'G2', 'G1', 'G1', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G1', 'G4', 'G2', 'G1', 'G2', 'G2', 'G2', 'G1', 'G1', 'G1', 'G2', 'G2', 'G1', 'G1', 'G4', 'G1', 'G1', 'G1', 'G2', 'G2', 'G2', 'G2', 'G1', 'G1', 'G2', 'G4', 'G2', 'G2', 'G1', 'G2', 'Outlier', 'G2', 'G1', 'G2', 'G1', 'G3', 'G2', 'G2', 'G3', 'G1', 'G1', 'G2', 'G2', 'G1', 'G3', 'G1', 'G2', 'G2', 'G1', 'G1', 'G2', 'G1', 'G2', 'G1', 'G1', 'G1', 'G2', 'G3', 'G1', 'G2', 'G1', 'G1', 'G2', 'G2', 'G2', 'G2', 'G5', 'G2', 'G1', 'G1', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G3', 'G2', 'G1', 'G2', 'G1', 'G2', 'G1', 'G1', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G1', 'G1', 'G2', 'G1', 'G1', 'G3', 'G2', 'G2', 'G1', 'Outlier', 'G1', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G1', 'G1', 'G1', 'G2', 'G2', 'G2', 'G2', 'G1', 'G1', 'G2', 'G2', 'G2', 'G5', 'G2', 'G5', 'Outlier', 'G2', 'G2', 'G2', 'G2', 'G3', 'Outlier', 'Outlier', 'G2', 'G2', 'G2', 'Outlier', 'G2', 'G1', 'G2', 'G2', 'Outlier', 'G2', 'G1', 'G2', 'G2', 'G1', 'G1', 'G2', 'G1', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G1', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G2', 'G3', 'G5', 'G2', 'G2', 'G1', 'G1', 'G3', 'G2', 'G2', 'G5', 'G3', 'G1', 'G2', 'G1', 'G1', 'G2', 'G1', 'G2', 'G2', 'Outlier', 'G1', 'G2', 'G1', 'G2', 'G1', 'G2', 'G1', 'G2', 'G2', 'G1', 'G2', 'G2', 'G2', 'G1', 'G2', 'G4', 'G2', 'G4', 'G1', 'G2', 'G2', 'G1', 'G5', 'G2', 'G2', 'G1', 'Outlier', 'G3', 'G1', 'G1', 'G1', 'G2', 'G1', 'G2', 'G2', 'G3', 'G2', 'G1', 'G1', 'G2', 'G2', 'G1', 'G2', 'G1', 'G1', 'G2', 'G2', 'G1', 'G2', 'G3', 'G1', 'G2', 'G2', 'G2', 'G1', 'G2', 'G1', 'G2', 'G1', 'G1', 'G2', 'G1', 'G2', 'G2', 'G3', 'G2', 'G3', 'G1', 'G2', 'G2', 'G2', 'G2', 'G1', 'G2', 'G3', 'G1', 'G2', 'G1', 'G1',  ...

# %%
#add new column to the data frame
test_phase_2['Segments']= seg

# %%
#Look at outlier count
test_phase_2['Segments'].value_counts()
# Out:
# Segments
# G2         28929
# G1         15627
# G3          2134
# Outlier     1379
# G4          1111
# G5           820
# Name: count, dtype: int64

# %%
############################     Make a K-Means Model (Advanced Task)    #######################################################
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
kframe = pd.read_csv(r"C:\Users\Nicholas Jones\Desktop\PythonStuff\Top_Perk.csv")

# %%
kframe.drop_duplicates()
kframe.session_id.isna().value_counts()
kframe.session_id.apply(lambda x:str(x))
kframe.session_id.info
kframe.avg_hotel_occ_daily.isna().value_counts()
kframe.avg_hotel_occ_daily.fillna(0)
kframe['avg_hotel_occ_daily'] = test_phase_2.avg_hotel_occ_daily.fillna(0)
kframe.total_bags.isna().value_counts()
kframe.total_bags.fillna(0)
kframe['total_bags']= test_phase_2.total_bags.fillna(0)
kframe.vacation_daily_difference.isna().value_counts()
kframe.vacation_daily_difference.fillna(0)
kframe['vacation_daily_difference']=test_phase_2.vacation_daily_difference.fillna(0)
kframe.total_flight_discount_amt.isna().value_counts()
kframe.total_flight_discount_amt.fillna(0)
kframe['total_flight_discount_amt']=test_phase_2.total_flight_discount_amt.fillna(0)
kframe.total_hotel_discount_amt.isna().value_counts()
kframe.total_hotel_discount_amt.fillna(0)
kframe['total_hotel_discount_amt']=test_phase_2.total_hotel_discount_amt.fillna(0)
kframe.no_cancel_num.isna().value_counts()
kframe.no_cancel_num.fillna(0)
kframe['no_cancel_num']=test_phase_2.no_cancel_num.fillna(0)
kframe.all_discounts.isna().value_counts()
kframe.all_discounts.fillna(0)
kframe['all_discounts']=test_phase_2.all_discounts.fillna(0)
kframe.original_pay.isna().value_counts()
kframe.original_pay.fillna(0)
kframe['original_pay']=test_phase_2.original_pay.fillna(0)

# %%
#############################      Data Frame with metrics      ##############
kset = kframe[['avg_hotel_occ_daily','total_bags','no_cancel_num','all_discounts','original_pay']]

# %%
skaler = StandardScaler()

# %%
###########Create K-Means************
kmeans = KMeans(n_clusters=5)

# %%
kset[['avg_hotel_occ_daily_T','total_bags_T','no_cancel_num_T','all_discounts_T','original_pay_T']]=skaler.fit_transform(kset[['avg_hotel_occ_daily','total_bags','no_cancel_num','all_discounts','original_pay']])
kset
# Out:
# C:\Users\Nicholas Jones\AppData\Local\Temp\ipykernel_6076\445368881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kset[['avg_hotel_occ_daily_T','total_bags_T','no_cancel_num_T','all_discounts_T','original_pay_T']]=skaler.fit_transform(kset[['avg_hotel_occ_daily','total_bags','no_cancel_num','all_discounts','original_pay']])
# C:\Users\Nicholas Jones\AppData\Local\Temp\ipykernel_6076\445368881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kset[['avg_hotel_occ_daily_T','total_bags_T','no_cancel_num_T','all_discounts_T','original_pay_T']]=skaler.fit_transform(kset[['avg_hotel_occ_daily','total_bags','no_cancel_num','all_discounts','original_pay']])
# C:\Users\Nicholas Jones\AppData\Local\Temp\ipykernel_6076\445368881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kset[['avg_hotel_occ_daily_T','total_bags_T','no_cancel_num_T','all_discounts_T','original_pay_T']]=skaler.fit_transform(kset[['avg_hotel_occ_daily','total_bags','no_cancel_num','all_discounts','original_pay']])
# C:\Users\Nicholas Jones\AppData\Local\Temp\ipykernel_6076\445368881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kset[['avg_hotel_occ_daily_T','total_bags_T','no_cancel_num_T','all_discounts_T','original_pay_T']]=skaler.fit_transform(kset[['avg_hotel_occ_daily','total_bags','no_cancel_num','all_discounts','original_pay']])
# C:\Users\Nicholas Jones\AppData\Local\Temp\ipykernel_6076\445368881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kset[['avg_hotel_occ_daily_T','total_bags_T','no_cancel_num_T','all_discounts_T','original_pay_T']]=skaler.fit_transform(kset[['avg_hotel_occ_daily','total_bags','no_cancel_num','all_discounts','original_pay']])
#        avg_hotel_occ_daily  total_bags  no_cancel_num  all_discounts  \
# 0                 0.091042         0.0       0.117647       0.000000
# 1                 0.021751         0.0       0.000000       0.000000
# 2                 0.245203         0.0       0.000000       0.000000
# 3                 0.021751         0.0       0.000000       0.000000
# 4                 0.021751         0.0       0.000000       0.352941
# ...                    ...         ...            ...            ...
# 49995             0.021751         0.0       0.000000       0.000000
# 49996             0.061142         0.0       0.117647       0.000000
# 49997             0.031492         0.0       0.117647       0.000000
# 49998             0.021751         0.0       0.000000       0.000000
# 49999             0.021751         0.0       0.000000       0.000000
#
#        original_pay  avg_hotel_occ_daily_T  total_bags_T  no_cancel_num_T  \
# 0          0.009707               0.551074     -0.506303         0.777653
# 1          0.000000              -0.605721     -0.506303        -0.718064
# 2          0.000000               3.124723     -0.506303        -0.718064
# 3          0.036025              -0.605721     -0.506303        -0.718064
# 4          0.000000              -0.605721     -0.506303        -0.718064
# ...             ...                    ...           ...              ...
# 49995      0.000000              -0.605721     -0.506303        -0.718064
# 49996      0.011244               0.051902     -0.506303         0.777653
# 49997      0.007524              -0.443101     -0.506303         0.777653
# 49998      0.002504              -0.605721     -0.506303        -0.718064
# 49999      0.000000              -0.605721     -0.506303        -0.718064
#
#        all_discounts_T  original_pay_T
# 0            -0.149926       -0.160640
# 1            -0.149926       -0.378480
# 2            -0.149926       -0.378480
# 3            -0.149926        0.429978
# 4             6.864694       -0.378480
# ...                ...             ...
# 49995        -0.149926       -0.378480
# 49996        -0.149926       -0.126142
# 49997        -0.149926       -0.209632
# 49998        -0.149926       -0.322279
# 49999        -0.149926       -0.378480
#
# [50000 rows x 10 columns]

# %%
df1 = kset.iloc[:,[6,7]].values

# %%
# The other variables compared to "avg_hotel_occ_daily"
list1 = []
for k in range(1,6):
    kmeans =KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(df1)
    list1.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,6), list1, linewidth=2, color="red",marker="*")
plt.xlabel("K-Value")
plt.ylabel("avg_hotel_occ_daily_T & total_bags_T")
plt.show()
# Out:
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
#Get labels
kmeans = KMeans(n_clusters=3)
label = kmeans.fit_predict(df1)
print(label)
# Out:
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1 0 0 ... 1 0 0]

# %%
#Get centroids
print(kmeans.cluster_centers_)
# Out:
# [[-0.38898928 -0.71806401]
#  [-0.50630261  1.00300675]
#  [ 1.52909339  1.02237173]]

# %%
#Create scatterplot and plot the centroids
plt.scatter(df1[:,0], df1[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color = 'black')
plt.title("Clusters of Customers")
plt.xlabel("avg_hotel_occ_daily")
plt.ylabel("total_bags")
plt.show()

# %%
# The other variables compared to "avg_hotel_occ_daily"
df2 = kset.iloc[:,[6,8]].values
list2 = []
for k in range(1,6):
    kmeans =KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(df2)
    list2.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,6), list2, linewidth=2, color="red",marker="*")
plt.xlabel("K-Value")
plt.ylabel("avg_hotel_occ_daily & No_Cancel_Num")
plt.show()
kmeans = KMeans(n_clusters=3)
label = kmeans.fit_predict(df2)
print(label)
print(kmeans.cluster_centers_)
plt.scatter(df2[:,0], df2[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color = 'black')
plt.title("Clusters of Customers")
plt.xlabel("avg_hotel_occ_daily")
plt.ylabel("No Cancel Num")
plt.show()
# Out:
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [0 0 0 ... 0 0 0]
# [[-0.50630261 -0.1448231 ]
#  [ 1.46663455 -0.14575177]
#  [-0.13152802  5.91944108]]

# %%
# The other variables compared to "avg_hotel_occ_daily"
df3 = kset.iloc[:,[6,9]].values
list3 = []
for k in range(1,6):
    kmeans =KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(df3)
    list3.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,6), list3, linewidth=2, color="red",marker="*")
plt.xlabel("K-Value")
plt.ylabel("total_bags & ALL_Discounts")
plt.show()
kmeans = KMeans(n_clusters=3)
label = kmeans.fit_predict(df3)
print(label)
print(kmeans.cluster_centers_)
plt.scatter(df3[:,0], df3[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color = 'black')
plt.title("Clusters of Customers")
plt.xlabel("avg_hotel_occ_daily")
plt.ylabel("ALL_Discounts")
plt.show()
# Out:
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [0 0 0 ... 0 0 0]
# [[-0.50630261 -0.2058645 ]
#  [ 1.35515298  0.14248393]
#  [ 2.62766128  5.34116373]]

# %%
# The other variables compared to "total_bags"
df5 = kset.iloc[:,[7,8]].values
list5 = []
for k in range(1,6):
    kmeans =KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(df5)
    list5.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,6), list5, linewidth=2, color="red",marker="*")
plt.xlabel("K-Value")
plt.ylabel("total_bags & No_Cancel_Num")
plt.show()
kmeans = KMeans(n_clusters=3)
label = kmeans.fit_predict(df5)
print(label)
print(kmeans.cluster_centers_)
plt.scatter(df5[:,0], df5[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color = 'black')
plt.title("Clusters of Customers")
plt.xlabel("total_bags")
plt.ylabel("No_Cancel_Num")
plt.show()
# Out:
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [1 0 0 ... 1 0 0]
# [[-0.71806401 -0.14492913]
#  [ 1.06065658 -0.14638039]
#  [-0.12637214  5.90762474]]

# %%
# The other variables compared to "total_bags"
df6 = kset.iloc[:,[7,9]].values
list6 = []
for k in range(1,6):
    kmeans =KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(df6)
    list6.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,6), list6, linewidth=2, color="red",marker="*")
plt.xlabel("K-Value")
plt.ylabel("total_bags & All_Discounts")
plt.show()
kmeans = KMeans(n_clusters=3)
label = kmeans.fit_predict(df6)
print(label)
print(kmeans.cluster_centers_)
plt.scatter(df6[:,0], df6[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color = 'black')
plt.title("Clusters of Customers")
plt.xlabel("total_bags")
plt.ylabel("All_Discounts")
plt.show()
# Out:
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [0 1 1 ... 0 1 1]
# [[ 1.0317188   0.10444235]
#  [-0.71806401 -0.2816468 ]
#  [ 0.40789664  5.25461369]]

# %%
# The other variables compared to "No_Cancel_Num"
df8 = kset.iloc[:,[8,9]].values
list8 = []
for k in range(1,6):
    kmeans =KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(df8)
    list8.append(kmeans.inertia_)
plt.figure(figsize=(12,6))
plt.grid()
plt.plot(range(1,6), list8, linewidth=2, color="red",marker="*")
plt.xlabel("K-Value")
plt.ylabel("No_Cancel_Num & All_Discounts")
plt.show()
kmeans = KMeans(n_clusters=3)
label = kmeans.fit_predict(df8)
print(label)
print(kmeans.cluster_centers_)
plt.scatter(df8[:,0], df8[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], color = 'black')
plt.title("Clusters of Customers")
plt.xlabel("No_Cancel_Num")
plt.ylabel("All_Discounts")
plt.show()
# Out:
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Nicholas Jones\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# [0 0 0 ... 0 0 0]
# [[-0.14545017 -0.13081078]
#  [-0.12495288  5.03052032]
#  [ 5.91865007 -0.11690585]]

# %%
######   Top Perk Dashboard Data set (Advanced Task) ########
tperk = test_phase_2[['avg_hotel_occ_daily','total_bags','no_cancel_num','all_discounts','original_pay', 'Segments','vacation_daily_difference']]
tperk.to_csv(r'C:\Users\Nicholas Jones\Desktop\Top_Perk_Dash.csv', index=False)
